# %% [markdown]
# Análise exploratória inicial (EDA): entender schema, tipos de dados e relações antes de modelar.

# %%
import pandas as pd
orders = pd.read_csv(r'C:\Users\Gustavo Santos\Desktop\Gustavo\pipeline_ecommerce\data-raw\olist_orders_dataset.csv')

# %%
print(orders.shape, orders.dtypes)
# Out:
# (99441, 8) order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object

# %%
print(orders.isnull().sum())
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
